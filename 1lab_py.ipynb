# %% [markdown]
# <a href="https://colab.research.google.com/github/chettuprasanna/Software-Engineering-lab/blob/master/1lab_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
def Quadratic_model(time,a,b,c):

  temperature = a * (time**2) + b * time + c
  return temperature

def main():
    a = 0.1
    b = -1
    c = 50
    time_values=np.linspace(0,10,50)
    temperature_hardcode=Quadratic_model(time_values, a,b,c)
    plt.plot(time_values , temperature_hardcode,label=f"hardcoded values:{a,b,c}")
    plt.xlabel('time')
    plt.ylabel('temperature')
    plt.legend()
    plt.title('weather modeling with quadratic equation')
    plt.show()
if __name__=="__main__":
    main()

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
import numpy as np
import matplotlib.pyplot as plt

def Quadratic_model(time, a, b, c):
    temperature = a * (time**2) + b * time + c
    return temperature

def main():
    a = float(input("Enter the value of a: "))
    b = float(input("Enter the value of b: "))
    c = float(input("Enter the value of c: "))

    time_values = np.linspace(0, 10, 50)
    temperature_hardcode = Quadratic_model(time_values, a, b, c)

    plt.plot(time_values, temperature_hardcode, label=f"user given values: {a, b, c}")
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.title('Weather Modeling with Quadratic Equation')
    plt.grid(True)
    plt.legend()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Enter the value of a: -1.0
# Enter the value of b: 20
# Enter the value of c: 30

# %%
import matplotlib.pyplot as plt
import numpy as np

def Quadratic_model(time, a, b, c):
    temperature = a * (time**2) + b * time + c
    return temperature

def Quadratic_model2(time, a, b, c):
    temperature = a * (time**2) + b * time + c
    return temperature

def main():
    a = 0.1
    b = -1
    c = 50
    a1 = float(input("Enter the value of a: "))
    b1 = float(input("Enter the value of b: "))
    c1 = float(input("Enter the value of c: "))
    time_values = np.linspace(0, 10, 50)
    temperature_hardcode = Quadratic_model(time_values, a, b, c)
    plt.plot(time_values, temperature_hardcode, label=f"hardcode values: {a, b, c}")
    temperature_user = Quadratic_model2(time_values, a1, b1, c1)
    plt.plot(time_values, temperature_user, label=f"user given values: {a1, b1, c1}")
    plt.xlabel('Time')
    plt.ylabel('Temperature')
    plt.title('Weather Modeling with Quadratic Equation')
    plt.grid(True)
    plt.legend()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Enter the value of a: -1.0
# Enter the value of b: 2.
# Enter the value of c: 30

# %%
import matplotlib.pyplot as plt
import numpy as np

def quad_model(Time, coeffs):
    a, b, c = coeffs
    temp = a * (Time**2) + b * Time + c
    return temp

def main():
    num_sets = int(input("Enter the number of coefficient sets: "))
    all_sets = []

    for _ in range(num_sets):
        a = float(input("Enter the value of 'a': "))
        b = float(input("Enter the value of 'b': "))
        c = float(input("Enter the value of 'c': "))
        all_sets.append((a, b, c))

    print("Give a time range:")
    x = float(input("Enter the start range: "))
    y = float(input("Enter the final range: "))

    time_v = np.linspace(x, y, 50)

    plt.figure(figsize=(8, 6))
    for coeffs in all_sets:
        temp_user = quad_model(time_v, coeffs)
        plt.plot(time_v, temp_user, label=f"Set: {coeffs}")

    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.legend()
    plt.title("Weather modeling with user given coefficient sets")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
  main()
# Out:
# Enter the number of coefficient sets: 4
# Enter the value of 'a': 6
# Enter the value of 'b': 7
# Enter the value of 'c': 9
# Enter the value of 'a': 10
# Enter the value of 'b': 4
# Enter the value of 'c': 5
# Enter the value of 'a': 6
# Enter the value of 'b': 8
# Enter the value of 'c': 3
# Enter the value of 'a': 8
# Enter the value of 'b': 7
# Enter the value of 'c': 11
# Give a time range:
# Enter the start range: 0
# Enter the final range: 15

# %%
import numpy as np
import matplotlib.pyplot as plt

def Quadratic_model(time, a, b, c):
    temperature = a * (time**2) + b * time + c
    return temperature

def main():
    with open("value.txt", "r") as file:
        lines = file.readlines()
        a, b, c = map(float, lines)
        print(f"Read values a={a}, b={b}, c={c}")

        print("give a time range")
        x = int(input("enter the start range: "))
        y = int(input("enter the end range: "))
        time_v = np.linspace(x, y, 50)
        temp_user = [Quadratic_model(t, a, b, c) for t in time_v]

        plt.plot(time_v, temp_user, label=f"file given values: {a, b, c}")
        plt.xlabel('Time')
        plt.ylabel('Temperature')
        plt.title('Weather Modeling with Quadratic Equation')
        plt.grid(True)  # Adding grid for better visualization
        plt.legend()
        plt.show()

if __name__ == "__main__":
    main()
# Out:
# Read values a=0.1, b=-1.0, c=50.0
# give a time range
# enter the start range: 10
# enter the end range: 20

# %%
import matplotlib.pyplot as plt
import numpy as np

def quad_model(Time, coeffs):
    a, b, c = coeffs
    temp = a * (Time**2) + b * Time + c
    return temp

def main():
    # Input coefficients as a set
    set1 = {float(input("Enter the value of 'a': ")), float(input("Enter the value of 'b': ")), float(input("Enter the value of 'c': "))}
    print(set1)
    print("Give a time range:")
    x = float(input("Enter the start range: "))
    y = float(input("Enter the final range: "))

    time_v = np.linspace(x, y, 50)
    temp_user = quad_model(time_v, set1)

    plt.plot(time_v, temp_user, label="user given values")
    plt.xlabel("time")
    plt.ylabel("temp")
    plt.legend()
    plt.title("Weather modeling with user given values and range in QE")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Enter the value of 'a': 10
# Enter the value of 'b': 15
# Enter the value of 'c': 5
# {10.0, 5.0, 15.0}
# Give a time range:
# Enter the start range: 0
# Enter the final range: 20
